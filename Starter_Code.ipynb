# %% [markdown]
# #   Charity Funding Report

# %% [markdown]
# ## Overview of the analysis: Explain the purpose of this analysis.
#
# To design binary classifier using deep learning algorithm that is capable of predicting whether applicants will be successful if funded by Alphabet Soup.
#
#
# ## Data Preprocessing
#
# 1. What variable(s) are considered the target(s) for your model?
# - The target variable is IS_SUCCESSFUL
#
# 2. What variable(s) are considered to be the features for your model?
# - The rest the variables are feature variables except Name and EIN
#
# 3. What variable(s) are neither targets nor features, and should be removed from the input data?
# -  Name and EIN
#
# ## Compiling, Training, and Evaluating the Model
#
# 1. How many neurons, layers, and activation functions did you select for your neural network model, and why?
# - Totally I used 231 neuron in 3 hidden layers
# - For internal layer I used Relu , but for final layer since its classification problem I used sigmoid.
#
# 2. Were you able to achieve the target model performance?
# - I was not able to increse the accuracy more than 74%
#
# 3. What steps did you take to try and increase model performance?
# - I tried to increase the neuron, hidden layer and epoch
#
#
#
#
#
# ## Summary: Summarize the overall results of the deep learning model. Include a recommendation for how a different model could solve this classification problem, and explain your recommendation.
#
# - Here I utilized simple deep learning model for classification problem with 74 % accuracy.Deep learning is efficient when we have huge data.
# - Since our dataset is not huge, given a chance I would have tried XG Boost classifier to solve this problem, as its effiencient model since it gives more importance when predictor is misclassified

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE

application_df.drop(columns=['EIN', 'NAME'], axis = 1, inplace = True)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
#  YOUR CODE GOES HERE

count = application_df['APPLICATION_TYPE'].value_counts()
count
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
application_types_to_replace = list(count[count < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE

count_c = application_df['CLASSIFICATION'].value_counts()
count_c
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C1900        1
# C6100        1
# C1728        1
# C1283        1
# C3700        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE

count_c[count_c > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C2300       32
# C7200       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C6000       15
# C1800       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1237        9
# C1235        9
# C7210        7
# C1720        6
# C4100        6
# C2400        6
# C1257        5
# C1600        5
# C0           3
# C1260        3
# C2710        3
# C1246        2
# C3200        2
# C1267        2
# C1256        2
# C1234        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classifications_to_replace = list(count_c[count_c < 1800].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE

application_df = pd.get_dummies(application_df, drop_first=True)
application_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  \
# 0       1     5000              1                     1                     0
# 1       1   108590              1                     0                     0
# 2       1     5000              0                     0                     0
# 3       1     6692              1                     0                     0
# 4       1   142590              1                     0                     0
#
#    APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  \
# 0                    0                    0                    0
# 1                    1                    0                    0
# 2                    0                    0                    1
# 3                    1                    0                    0
# 4                    1                    0                    0
#
#    APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  ...  ORGANIZATION_Trust  \
# ...

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE

X = application_df.drop(['IS_SUCCESSFUL'], axis = 1).values
y = application_df['IS_SUCCESSFUL'].values

# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=18, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE


input_features = len(X_train[0])
nn = tf.keras.models.Sequential()
# First hidden layer
#  YOUR CODE GOES HERE

nn.add(
    tf.keras.layers.Dense(units=100, input_dim=input_features, activation="relu")
)

# Second hidden layer
#  YOUR CODE GOES HERE

nn.add(tf.keras.layers.Dense(units=80, activation="relu"))

# Third hidden layer
#  YOUR CODE GOES HERE

nn.add(tf.keras.layers.Dense(units=50, activation="relu"))

# Output layer
#  YOUR CODE GOES HERE

nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 100)               3700
#
#  dense_5 (Dense)             (None, 80)                8080
#
#  dense_6 (Dense)             (None, 50)                4050
#
#  dense_7 (Dense)             (None, 1)                 51
#
# ...
# Total params: 15,881
# Trainable params: 15,881
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE

nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE

fit_model = nn.fit(X_train_scaled, y_train, epochs=150)
# Out:
# Epoch 1/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5725 - accuracy: 0.7207
# Epoch 2/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5571 - accuracy: 0.7296
# Epoch 3/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5539 - accuracy: 0.7308
# Epoch 4/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5520 - accuracy: 0.7317
# Epoch 5/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5503 - accuracy: 0.7327
# Epoch 6/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5499 - accuracy: 0.7332
# Epoch 7/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5482 - accuracy: 0.7327
# Epoch 8/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5480 - accuracy: 0.7344
# Epoch 9/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5472 - accuracy: 0.7337
# Epoch 10/150
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5955 - accuracy: 0.7282 - 347ms/epoch - 1ms/step
# Loss: 0.5954578518867493, Accuracy: 0.7281632423400879

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE

nn.save('Charity-funding.h5')
